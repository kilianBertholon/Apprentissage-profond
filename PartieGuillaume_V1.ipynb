# %% [markdown]
# <a href="https://colab.research.google.com/github/kilianBertholon/Apprentissage-profond/blob/main/PartieGuillaume_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> Rendu Projet Apprentissage Profond </center>

# %%
# !git clone https://github.com/kilianBertholon/Apprentissage-profond.git
# Out:
# Cloning into 'Apprentissage-profond'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 65 (delta 16), reused 7 (delta 1), pack-reused 32
# Receiving objects: 100% (65/65), 106.38 MiB | 14.07 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Updating files: 100% (34/34), done.

# %% [markdown]
# Kilian Bertholon
# Guillaume Cobat
# Placé Anthony

# %%
import csv
import os
import json
import numpy as np

def load_data(nom_dossier="."):
    """
    Fonction de chargement des données
    Attention : Utilise les librairies csv et json. S'assurer que le répertoire de travail est celui où se trouve
    la fonction data_loading.py (sans déplacer les différents fichiers)
    """

    info_obs = {}
    users = []

    print("-- chargement des fichiers csv (observations + labels) --")
    dataset = []
    user_ids = []
    labels = []
    for dir_files in os.listdir(nom_dossier):
        if os.path.isfile(nom_dossier + "/" + dir_files) and dir_files[-3:]=='csv':
            user_id = dir_files.split('_')[0]
            print("Data ", user_id)
            users.append(user_id)
            cur_series = []
            cur_labels = []
            with open(nom_dossier + "/" + dir_files, newline='') as csvfile:
                spamreader = csv.reader(csvfile, delimiter=',', quotechar='\'')
                for i,row in enumerate(spamreader):
                    if i==0:
                        info_obs['observations'] = row[2:5]
                        info_obs['labels'] = row[7]
                    else:
                        cur_series.append([float(v) for v in row[2:5]])
                        cur_labels.append(row[7])
            segmented_series = []
            segmented_labels = []
            cur_lab = "not_labeled"
            cur_ser = []
            for i, (v, l) in enumerate(zip(cur_series, cur_labels)):
                if l != cur_lab:
                    if cur_lab != "not_labeled":
                        segmented_series.append(np.array(cur_ser))
                        segmented_labels.append(cur_lab)
                    cur_ser = []
                    cur_lab = l
                if l != "not_labeled":
                    cur_ser.append(v)
        dataset.extend(segmented_series)
        labels.extend(segmented_labels)
        user_ids.extend([user_id] * len(segmented_series))


    print("-- chargement du fichier json (meta données) --")
    # Opening JSON file
    f = open(os.path.join(nom_dossier, 'meta.json'))
    # returns JSON object as a dictionary
    tmp_meta_data = json.load(f)
    meta_data = {}
    for origin in tmp_meta_data:
        for user_id, user_info in tmp_meta_data[origin].items():
            meta_data[user_id] = user_info
            meta_data[user_id]['origin'] = origin
    # Closing file
    f.close()

    return dataset, labels, user_ids  # info_obs, meta_data

print("Lecture des données")
data_obs, data_labels, user_ids = load_data("Apprentissage-profond/hangtime_har/")
print("Données chargées")

print(data_obs[:5])
print(data_labels[:5])
print(user_ids[:5])
# Out:
# Lecture des données
# -- chargement des fichiers csv (observations + labels) --
# Data  f2ad
# Data  0846
# Data  a0da
# Data  ce9d
# Data  c6f3
# Data  2dd9
# Data  9bd4
# Data  ac59
# Data  b512
# Data  2dd9
# Data  e90f
# Data  f2ad
# Data  10f0
# Data  4991
# Data  10f0
# Data  0846
# Data  ac59
# Data  b512
# Data  ce9d
# Data  4d70
# Data  a0da
# Data  9bd4
# Data  4d70
# Data  05d8
# -- chargement du fichier json (meta données) --
# Données chargées
# [array([[-8.696300e-01,  4.062500e-01, -7.570000e-03],
#        [-8.453350e-01,  3.846450e-01, -7.690000e-03],
#        [-8.210400e-01,  3.630400e-01, -7.810000e-03],
#        [-8.430200e-01,  3.161600e-01, -1.880000e-02],
#        [-8.664600e-01,  2.849100e-01, -3.320000e-02],
#        [-9.113800e-01,  2.890600e-01, -4.565000e-02],
#        [-9.899900e-01,  3.278800e-01, -7.886000e-02],
#        [-1.053470e+00,  3.767100e-01, -7.349000e-02],
#        [-1.183590e+00,  4.177200e-01, -4.688000e-02],
#        [-1.285890e+00,  3.295900e-01, -1.562000e-02],
#        [-1.391600e+00, -5.727500e-01,  3.166500e-01],
#        [-1.146730e+00, -8.818400e-01,  3.261700e-01],
#        [-1.263920e+00, -8.906200e-01,  4.226100e-01],
#        [-1.228760e+00, -8.964800e-01,  6.499000e-01],
#        [-1.285640e+00, -8.508300e-01,  7.685500e-01],
#        [-1.412840e+00, -9.150400e-01,  8.181200e-01],
#        [-1.507080e+00, -1.037600e+00,  9.126000e-01],
#        [-1.699950e+00, -9.904800e-01,  9.467800e-01],
#        [-1.960940e+00, -8.234900e-01,  8.107900e-01],
#        [-2.104250e+00, -7.800300e-01,  6.772500e-01],
#        [-2.111080e+00, -1.017580e+00,  7.041000e-01],
#        [-2.170900e+00, -1.141110e+00,  7.329100e-01],
#        [-2.176880e+00, -1.114500e+00,  6.967750e-01],
#        [-2.182860e+00, -1.087890e+00,  6.606400e-01],
#        [-2.061280e+00, -1.111820e+00,  5.065900e-01],
#        [-1.905760e+00, -1.281980e+00,  3.886700e-01],
#        [-1.861080e+00, -1.235110e+00,  5.298000e-02],
#        [-1.855710e+00, -9.067400e-01, -3.466800e-01],
#        [-1.634770e+00, -8.496100e-01, -5.239300e-01],
#        [-1.415770e+00, -7.529300e-01, -5.773900e-01],
#        [-1.260740e+00, -3.754900e-01, -7.678200e-01],
#        [-1.167240e+00,  1.682100e-01, -1.052250e+00],
#        [-1.107180e+00,  1.032960e+00, -1.272220e+00],
#        [-8.989300e-01,  1.400880e+00, -1.474120e+00],
#        [-4.890100e-01,  1.988770e+00, -1.324710e+00],
#        [-5.298000e-02,  2.754640e+00, -8.347200e-01],
#        [-4.567900e-01,  2.880860e+00, -1.069300e-01],
#        [-1.434080e+00,  3.378910e+00,  4.419000e-02],
#        [-3.127930e+00,  3.930660e+00, -6.030000e-02],
#        [-4.686040e+00,  4.104250e+00, -2.307100e-01],
#        [-6.510250e+00,  5.125240e+00, -6.057100e-01],
#        [-7.978030e+00,  7.072020e+00, -1.414790e+00],
#        [-7.997310e+00,  7.999760e+00, -2.253910e+00],
#        [-7.991455e+00,  7.972170e+00, -2.572510e+00],
#        [-7.985600e+00,  7.944580e+00, -2.891110e+00],
#        [-7.993650e+00,  7.988280e+00, -3.573000e+00],
#        [-7.988280e+00,  7.811280e+00, -4.022220e+00],
#        [-7.991700e+00,  6.985350e+00, -3.505130e+00],
#        [-7.955570e+00,  5.298340e+00, -2.284910e+00],
#        [-6.858150e+00,  3.576170e+00, -9.033200e-01],
#        [-4.896000e+00,  1.714600e+00,  8.105500e-01],
#        [-2.811520e+00, -1.132800e-01,  1.646480e+00],
#        [-1.556400e+00, -2.761200e-01,  1.083250e+00]]), array([[-0.79785 ,  0.17969 ,  0.01855 ],
#        [-0.85376 ,  0.21973 , -0.00269 ],
#        [-0.85815 ,  0.21094 , -0.01709 ],
#        [-0.91699 ,  0.19434 , -0.02832 ],
#        [-1.07275 ,  0.19067 , -0.05273 ],
#        [-1.21704 ,  0.21338 , -0.07837 ],
#        [-1.3064  ,  0.2417  , -0.0918  ],
#        [-1.335695,  0.256105, -0.106205],
#        [-1.36499 ,  0.27051 , -0.12061 ],
#        [-1.31689 ,  0.33203 , -0.18335 ],
#        [-1.13965 ,  0.34717 , -0.23413 ],
#        [-0.90942 ,  0.31689 , -0.26147 ],
#        [-0.73901 ,  0.28467 , -0.28662 ],
#        [-0.71631 ,  0.26758 , -0.28516 ],
#        [-0.79224 ,  0.27124 , -0.26294 ],
#        [-0.91382 ,  0.28198 , -0.24854 ],
#        [-1.05737 ,  0.27002 , -0.23022 ],
#        [-1.22949 ,  0.23706 , -0.21362 ],
#        [-1.41479 ,  0.21143 , -0.23584 ],
#        [-1.46094 ,  0.18457 , -0.29639 ],
#        [-1.2959  ,  0.17041 , -0.35254 ],
#        [-1.06616 ,  0.19995 , -0.36938 ],
#        [-0.92627 ,  0.22949 , -0.35327 ],
#        [-0.86768 ,  0.23462 , -0.31421 ],
#        [-0.85132 ,  0.27148 , -0.28369 ],
#        [-0.84717 ,  0.32129 , -0.26807 ],
#        [-0.8457  ,  0.34106 , -0.2583  ],
#        [-0.84033 ,  0.33716 , -0.25171 ],
#        [-0.838865,  0.32837 , -0.250855],
#        [-0.8374  ,  0.31958 , -0.25    ],
#        [-0.8374  ,  0.2854  , -0.25977 ],
#        [-0.81934 ,  0.26074 , -0.2583  ],
#        [-0.7937  ,  0.25049 , -0.25049 ],
#        [-0.7959  ,  0.24316 , -0.24878 ],
#        [-0.84106 ,  0.25635 , -0.24683 ],
#        [-0.92798 ,  0.27686 , -0.24878 ],
#        [-1.02271 ,  0.28271 , -0.2417  ],
#        [-1.09424 ,  0.27612 , -0.23145 ],
#        [-1.1416  ,  0.25659 , -0.21411 ],
#        [-1.16187 ,  0.23999 , -0.18652 ],
#        [-1.17334 ,  0.21729 , -0.15332 ],
#        [-1.22461 ,  0.18311 , -0.13086 ],
#        [-1.29639 ,  0.19214 , -0.13428 ],
#        [-1.29639 ,  0.22949 , -0.1416  ],
#        [-1.19897 ,  0.24829 , -0.14062 ],
#        [-1.04272 ,  0.26367 , -0.13721 ],
#        [-0.91797 ,  0.26196 , -0.12573 ],
#        [-0.83813 ,  0.25757 , -0.11646 ],
#        [-0.75049 ,  0.27271 , -0.11157 ],
#        [-0.72473 ,  0.277345, -0.10693 ],
#        [-0.69897 ,  0.28198 , -0.10229 ],
#        [-0.89648 ,  0.28149 , -0.09912 ],
#        [-1.07617 ,  0.28711 , -0.10889 ],
#        [-1.20483 ,  0.30054 , -0.10962 ],
#        [-1.27661 ,  0.32349 , -0.10522 ],
#        [-1.29272 ,  0.32202 , -0.09644 ],
#        [-1.21045 ,  0.26831 , -0.07324 ],
#        [-1.06079 ,  0.20728 , -0.04712 ],
#        [-0.91846 ,  0.15112 , -0.02588 ],
#        [-0.80005 ,  0.11792 , -0.01562 ],
#        [-0.74072 ,  0.14136 , -0.02075 ],
#        [-0.7439  ,  0.20386 , -0.03345 ],
#        [-0.78125 ,  0.27124 , -0.03394 ],
#        [-0.84326 ,  0.32568 , -0.03345 ],
#        [-0.90991 ,  0.3645  , -0.04517 ],
#        [-0.91382 ,  0.38013 , -0.03223 ],
#        [-0.88257 ,  0.3728  , -0.00806 ],
#        [-0.87695 ,  0.36084 , -0.0127  ],
#        [-0.88208 ,  0.32104 , -0.04224 ],
#        [-0.86694 ,  0.28052 , -0.04932 ],
#        [-0.86511 ,  0.26465 , -0.03455 ],
#        [-0.86328 ,  0.24878 , -0.01978 ],
#        [-0.87061 ,  0.22754 , -0.00903 ],
#        [-0.84277 ,  0.2356  , -0.01904 ],
#        [-0.81787 ,  0.25073 , -0.04907 ],
#        [-0.84448 ,  0.29272 , -0.10718 ],
#        [-0.91382 ,  0.34546 , -0.18188 ],
#        [-0.98828 ,  0.39917 , -0.24438 ],
#        [-1.0498  ,  0.43555 , -0.27368 ],
#        [-1.07959 ,  0.42432 , -0.27051 ],
#        [-1.05908 ,  0.35327 , -0.25024 ],
#        [-1.0144  ,  0.2356  , -0.21875 ],
#        [-1.05249 ,  0.10425 , -0.15601 ],
#        [-1.24951 ,  0.03418 , -0.14233 ],
#        [-1.38184 ,  0.05566 , -0.20605 ],
#        [-1.32129 ,  0.11353 , -0.29541 ],
#        [-1.1709  ,  0.18481 , -0.37817 ],
#        [-0.96851 ,  0.23267 , -0.42456 ],
#        [-0.7998  ,  0.24243 , -0.4126  ],
#        [-0.71558 ,  0.24438 , -0.37549 ],
#        [-0.68726 ,  0.24902 , -0.35498 ],
#        [-0.69458 ,  0.22485 , -0.35486 ],
#        [-0.7019  ,  0.20068 , -0.35474 ],
#        [-0.77124 ,  0.19751 , -0.37378 ],
#        [-0.86377 ,  0.34985 , -0.36353 ],
#        [-0.91528 ,  0.35693 , -0.31812 ],
#        [-0.94116 ,  0.26245 , -0.28027 ],
#        [-0.98486 ,  0.22485 , -0.25269 ],
#        [-1.00952 ,  0.14307 , -0.23071 ],
#        [-1.02368 ,  0.13184 , -0.21167 ],
#        [-1.05176 ,  0.18945 , -0.18311 ],
#        [-1.07349 ,  0.23877 , -0.15845 ],
#        [-1.08276 ,  0.2644  , -0.14624 ],
#        [-1.09424 ,  0.31763 , -0.14941 ],
#        [-1.13452 ,  0.38208 , -0.16284 ],
#        [-1.17383 ,  0.4248  , -0.17383 ],
#        [-1.13672 ,  0.44336 , -0.16846 ],
#        [-1.05273 ,  0.44678 , -0.15332 ],
#        [-0.9939  ,  0.45337 , -0.16553 ],
#        [-0.97998 ,  0.45679 , -0.18018 ],
#        [-0.97583 ,  0.5144  , -0.18433 ],
#        [-0.9397  ,  0.56763 , -0.22852 ],
#        [-0.908935,  0.596805, -0.270755],
#        [-0.87817 ,  0.62598 , -0.31299 ],
#        [-0.85938 ,  0.75879 , -0.44775 ],
#        [-0.89136 ,  0.82935 , -0.46265 ],
#        [-0.7998  ,  0.83105 , -0.4231  ],
#        [-0.66162 ,  0.89526 , -0.50586 ],
#        [-0.65771 ,  0.83862 , -0.69287 ],
#        [-0.71362 ,  0.74121 , -0.88184 ],
#        [-0.68408 ,  0.75195 , -0.99609 ],
#        [-0.64648 ,  0.71704 , -0.99341 ],
#        [-0.5791  ,  0.72437 , -0.98047 ],
#        [-0.57251 ,  0.76904 , -1.02002 ],
#        [-0.56274 ,  0.57642 , -0.94727 ],
#        [-0.40698 ,  0.3833  , -0.87329 ],
#        [-0.29761 ,  0.44653 , -0.88599 ],
#        [-0.24536 ,  0.50952 , -0.8855  ],
#        [-0.19067 ,  0.34619 , -0.82544 ],
#        [-0.08765 ,  0.22583 , -0.77393 ],
#        [-0.00781 ,  0.24609 , -0.73218 ],
#        [ 0.03076 ,  0.32642 , -0.74829 ],
#        [ 0.01221 ,  0.35205 , -0.76538 ],
#        [ 0.03699 ,  0.37158 , -0.6084  ],
#        [ 0.06177 ,  0.39111 , -0.45142 ],
#        [ 0.27222 ,  0.4729  , -0.3457  ],
#        [ 0.28638 ,  0.4812  , -0.4502  ],
#        [ 0.28687 ,  0.40991 , -0.51953 ],
#        [ 0.40308 ,  0.25952 , -0.52734 ],
#        [ 0.47681 ,  0.2395  , -0.57715 ],
#        [ 0.45435 ,  0.40649 , -0.67114 ],
#        [ 0.44775 ,  0.48901 , -0.70508 ],
#        [ 0.44019 ,  0.55273 , -0.69189 ],
#        [ 0.43726 ,  0.58887 , -0.69531 ],
#        [ 0.44604 ,  0.50317 , -0.69141 ],
#        [ 0.46362 ,  0.46924 , -0.63281 ],
#        [ 0.50806 ,  0.40161 , -0.58838 ],
#        [ 0.55981 ,  0.36548 , -0.59961 ],
#        [ 0.55322 ,  0.38525 , -0.64624 ],
#        [ 0.52148 ,  0.37793 , -0.6792  ],
#        [ 0.51001 ,  0.30933 , -0.69482 ],
#        [ 0.49927 ,  0.33301 , -0.68921 ],
#        [ 0.50464 ,  0.37354 , -0.67749 ],
#        [ 0.51855 ,  0.3916  , -0.6792  ],
#        [ 0.515255,  0.39441 , -0.693115],
#        [ 0.51196 ,  0.39722 , -0.70703 ],
#        [ 0.52344 ,  0.35815 , -0.71191 ],
#        [ 0.55225 ,  0.37036 , -0.71411 ],
#        [ 0.53662 ,  0.4314  , -0.74805 ],
#        [ 0.5249  ,  0.48413 , -0.79443 ],
#        [ 0.52295 ,  0.54102 , -0.85986 ],
#        [ 0.53296 ,  0.54126 , -0.88623 ],
#        [ 0.54663 ,  0.52661 , -0.8667  ],
#        [ 0.5249  ,  0.55322 , -0.85449 ],
#        [ 0.49438 ,  0.54175 , -0.8728  ],
#        [ 0.48291 ,  0.51489 , -0.90601 ],
#        [ 0.46582 ,  0.46167 , -0.93164 ],
#        [ 0.43384 ,  0.42383 , -0.93115 ],
#        [ 0.40479 ,  0.42163 , -0.93115 ],
#        [ 0.38037 ,  0.40552 , -0.92603 ],
#        [ 0.36157 ,  0.4187  , -0.89355 ],
#        [ 0.34668 ,  0.44897 , -0.86206 ],
#        [ 0.32471 ,  0.44336 , -0.84204 ],
#        [ 0.29541 ,  0.40601 , -0.84082 ],
#        [ 0.29565 ,  0.38965 , -0.83032 ],
#        [ 0.31384 ,  0.39807 , -0.819455],
#        [ 0.33203 ,  0.40649 , -0.80859 ],
#        [ 0.36133 ,  0.40747 , -0.80151 ],
#        [ 0.3916  ,  0.37451 , -0.78247 ],
#        [ 0.42334 ,  0.38989 , -0.75708 ],
#        [ 0.42456 ,  0.43799 , -0.76831 ],
#        [ 0.41577 ,  0.47046 , -0.81396 ],
#        [ 0.40552 ,  0.43359 , -0.86353 ]]), array([[ 0.40479 ,  0.34644 , -0.85718 ],
#        [ 0.4187  ,  0.33252 , -0.80762 ],
#        [ 0.40698 ,  0.35083 , -0.77856 ],
#        [ 0.39282 ,  0.3501  , -0.74976 ],
#        [ 0.39893 ,  0.36646 , -0.70654 ],
#        [ 0.41724 ,  0.37085 , -0.66284 ],
#        [ 0.43921 ,  0.36108 , -0.65063 ],
#        [ 0.4436  ,  0.36255 , -0.67456 ],
#        [ 0.4458  ,  0.34814 , -0.72021 ],
#        [ 0.47876 ,  0.34326 , -0.73047 ],
#        [ 0.51221 ,  0.40747 , -0.78369 ],
#        [ 0.54688 ,  0.42407 , -0.89111 ],
#        [ 0.64502 ,  0.3645  , -0.93994 ],
#        [ 0.682985,  0.33032 , -0.945435],
#        [ 0.72095 ,  0.29614 , -0.95093 ],
#        [ 0.70923 ,  0.22559 , -0.90063 ],
#        [ 0.73633 ,  0.17944 , -0.83008 ],
#        [ 0.81055 ,  0.17603 , -0.90845 ],
#        [ 1.00195 ,  0.13843 , -1.05859 ],
#        [ 1.26758 ,  0.35034 , -1.30566 ],
#        [ 1.45923 ,  1.3479  , -2.07739 ],
#        [ 1.53955 ,  1.13013 , -2.33667 ],
#        [ 1.52417 ,  0.52808 , -2.22388 ],
#        [ 1.68677 , -0.09058 , -1.79712 ],
#        [ 1.87549 , -0.8103  , -1.39575 ],
#        [ 1.87305 , -1.0459  , -1.14404 ],
#        [ 1.56665 , -0.74902 , -1.02319 ],
#        [ 1.0459  , -0.40381 , -0.81177 ],
#        [ 0.6604  , -0.30469 , -0.33911 ],
#        [ 0.07886 , -0.14722 ,  0.177   ],
#        [-0.07788 ,  0.34155 ,  0.52222 ],
#        [ 0.15063 , -0.07935 ,  0.77295 ],
#        [ 0.13354 , -0.5332  ,  0.78345 ],
#        [-0.42407 , -0.02539 , -0.67944 ],
#        [-0.69055 , -0.11731 , -0.45996 ],
#        [-0.95703 , -0.20923 , -0.24048 ],
#        [-0.11499 ,  1.67529 ,  2.20898 ],
#        [ 0.35522 ,  2.67407 ,  4.48999 ],
#        [-2.60986 ,  3.39233 ,  0.23975 ],
#        [ 0.63574 , -2.40601 ,  0.14258 ],
#        [-0.99927 , -1.42944 , -0.20996 ],
#        [-1.67944 ,  0.67578 , -0.37305 ],
#        [ 0.44043 , -2.09351 ,  1.01025 ],
#        [-1.71338 ,  0.01123 , -0.47998 ],
#        [-0.99756 ,  1.31396 ,  0.23926 ],
#        [-1.89307 ,  1.60181 , -0.76929 ],
#        [-1.4856  ,  1.13354 , -0.55396 ],
#        [-1.35889 ,  1.03101 , -0.57275 ],
#        [-0.65088 ,  0.48853 , -0.4104  ]]), array([[-3.867200e-01,  4.028300e-01, -1.550300e-01],
#        [ 2.937000e-01,  4.733900e-01, -1.557600e-01],
#        [ 4.189500e-01,  6.501500e-01, -1.064940e+00],
#        [ 5.811000e-02,  1.171140e+00, -1.920410e+00],
#        [-4.870600e-01,  2.186770e+00, -2.191410e+00],
#        [-4.702150e-01,  2.403320e+00, -2.250370e+00],
#        [-4.533700e-01,  2.619870e+00, -2.309330e+00],
#        [-5.361300e-01,  2.403810e+00, -2.010500e+00],
#        [-2.011470e+00,  2.086430e+00, -1.833740e+00],
#        [-2.600830e+00,  1.682100e-01, -2.420900e+00],
#        [-4.510250e+00,  5.847900e+00, -6.943400e-01],
#        [-9.733900e-01,  2.243900e+00, -8.325200e-01],
#        [-1.883790e+00,  3.760000e-02,  7.727100e-01],
#        [-3.713130e+00,  1.563230e+00,  3.395020e+00],
#        [-3.328370e+00, -4.751000e-01,  1.437990e+00],
#        [-4.271970e+00,  1.606400e-01,  9.863000e-02],
#        [-2.291020e+00, -1.696290e+00,  1.337900e-01],
#        [-2.978030e+00,  3.728000e-01,  1.420650e+00],
#        [-2.038570e+00,  3.676800e-01,  1.626220e+00],
#        [-2.015380e+00,  4.255400e-01,  5.869100e-01],
#        [-1.466800e+00, -1.689500e-01, -1.774900e-01],
#        [-5.744600e-01,  5.347000e-02, -6.679700e-01],
#        [ 2.143600e-01,  4.150000e-02, -7.177700e-01],
#        [ 6.940900e-01,  5.811000e-02, -6.657700e-01],
#        [ 8.303200e-01,  3.215300e-01, -1.154790e+00],
#        [ 6.162100e-01, -3.679200e-01, -1.739500e+00],
#        [ 6.445300e-01, -6.744400e-01, -1.761720e+00],
#        [ 6.728500e-01, -9.809600e-01, -1.783940e+00],
#        [ 7.004400e-01, -1.074200e-01, -1.805660e+00],
#        [ 2.297400e-01,  7.880900e-01, -2.097170e+00],
#        [-3.381300e-01,  8.061500e-01, -2.282470e+00],
#        [-6.870100e-01,  6.735800e-01, -2.312990e+00],
#        [-1.091310e+00,  1.081050e+00, -2.266850e+00],
#        [-1.709470e+00,  1.625000e+00, -2.345460e+00],
#        [-2.406490e+00,  1.783450e+00, -2.379880e+00],
#        [-3.054200e+00,  1.616210e+00, -1.975100e+00],
#        [-3.464110e+00,  1.490720e+00, -1.463620e+00],
#        [-3.928960e+00,  1.271240e+00, -9.416500e-01],
#        [-4.317870e+00,  1.315920e+00, -7.324000e-02],
#        [-3.935550e+00,  1.802000e+00,  1.001220e+00],
#        [-3.114750e+00,  1.785890e+00,  1.535890e+00],
#        [-2.786130e+00,  1.260990e+00,  1.656250e+00],
#        [-2.641110e+00,  9.987800e-01,  1.755130e+00],
#        [-2.232180e+00,  5.737300e-01,  1.727050e+00],
#        [-1.767330e+00,  1.665000e-01,  1.374510e+00],
#        [-1.354490e+00, -1.228000e-01,  7.348600e-01],
#        [-1.098880e+00, -5.161100e-01,  1.293900e-01],
#        [-1.055665e+00, -5.061000e-01,  6.250000e-02],
#        [-1.012450e+00, -4.960900e-01, -4.390000e-03],
#        [-1.041020e+00, -2.009300e-01, -2.043500e-01],
#        [-1.406980e+00, -7.300000e-04, -7.946800e-01],
#        [-2.197750e+00,  4.340800e-01, -1.567630e+00],
#        [-2.784420e+00,  1.173340e+00, -1.934330e+00],
#        [-3.088130e+00,  1.677000e+00, -2.127200e+00],
#        [-2.957030e+00,  1.870120e+00, -2.570560e+00],
#        [-2.271000e+00,  1.581540e+00, -2.441890e+00],
#        [-1.282470e+00,  1.039060e+00, -1.882570e+00],
#        [-1.147500e-01,  6.591800e-01, -1.357670e+00],
#        [ 1.048830e+00,  5.988800e-01, -9.353000e-01],
#        [ 2.082520e+00,  7.321800e-01, -7.788100e-01],
#        [ 2.510010e+00,  8.911100e-01, -8.918500e-01],
#        [ 2.406490e+00,  1.018310e+00, -9.399400e-01],
#        [ 1.861820e+00,  1.212890e+00, -1.194090e+00],
#        [ 8.718300e-01,  1.583250e+00, -1.915040e+00],
#        [-3.530300e-01,  1.755860e+00, -2.242680e+00],
#        [-1.321780e+00,  1.595210e+00, -2.060060e+00],
#        [-2.010500e+00,  1.243160e+00, -1.989260e+00],
#        [-2.552730e+00,  1.072020e+00, -2.048100e+00],
#        [-2.618895e+00,  1.164430e+00, -2.017090e+00],
#        [-2.685060e+00,  1.256840e+00, -1.986080e+00],
#        [-2.314700e+00,  1.199950e+00, -1.192870e+00],
#        [-5.976600e-01,  7.216800e-01, -6.718800e-01],
#        [-5.070800e-01,  3.200700e-01,  9.770000e-03],
#        [-4.416500e-01,  1.589400e-01,  3.479000e-01],
#        [-3.486300e-01, -5.518000e-02,  6.142600e-01],
#        [-3.042000e-01, -3.249500e-01,  8.378900e-01],
#        [-2.653800e-01, -4.016100e-01,  1.181880e+00],
#        [-6.665000e-02, -4.465300e-01,  1.461430e+00],
#        [ 1.235400e-01, -7.141100e-01,  1.299800e+00],
#        [ 1.879900e-01, -7.788100e-01,  1.013920e+00],
#        [ 3.378900e-01, -8.764600e-01,  8.825700e-01],
#        [ 4.243200e-01, -6.474600e-01,  5.502900e-01]]), array([[ 3.252000e-01,  9.030000e-03,  3.530300e-01],
#        [ 1.572300e-01,  1.527340e+00,  3.830600e-01],
#        [-2.186280e+00,  2.964360e+00, -5.332000e-01],
#        [-4.052490e+00,  2.231450e+00, -5.024410e+00],
#        [-2.316160e+00,  1.508540e+00,  6.831100e-01],
#        [-2.580810e+00,  1.146970e+00,  2.552250e+00],
#        [-4.333250e+00,  1.555420e+00,  9.089400e-01],
#        [-4.435670e+00,  1.504515e+00,  1.970950e+00],
#        [-4.538090e+00,  1.453610e+00,  3.032960e+00],
#        [-4.100830e+00,  6.001000e-01,  1.798340e+00],
#        [-2.892330e+00,  1.028320e+00,  1.832520e+00],
#        [-1.616700e+00,  1.024410e+00,  1.171140e+00],
#        [-9.323700e-01,  1.093750e+00,  1.423100e+00],
#        [-4.213900e-01,  8.222700e-01,  1.012210e+00],
#        [ 3.439900e-01,  1.616200e-01,  1.609130e+00],
#        [ 6.503900e-01, -1.855000e-02,  1.299800e+00],
#        [ 6.743200e-01, -8.765000e-02,  1.152830e+00],
#        [ 7.575700e-01, -1.257300e-01,  8.815900e-01],
#        [ 1.171630e+00, -4.431200e-01,  7.736800e-01],
#        [ 1.806880e+00, -6.623500e-01,  4.680200e-01],
#        [ 2.285890e+00, -5.183100e-01,  3.972200e-01],
#        [ 2.607910e+00, -6.592000e-02,  7.363300e-01],
#        [ 2.833980e+00,  7.128900e-01,  1.661870e+00],
#        [ 1.237060e+00,  2.865230e+00,  3.639400e+00],
#        [-2.403080e+00,  6.530520e+00,  5.122310e+00],
#        [-4.084720e+00,  7.266360e+00,  4.668950e+00],
#        [-3.302490e+00,  5.939450e+00,  2.500490e+00],
#        [-2.275150e+00,  5.117920e+00,  1.287110e+00],
#        [-2.046145e+00,  4.322875e+00,  1.204470e+00],
#        [-1.817140e+00,  3.527830e+00,  1.121830e+00],
#        [-1.610110e+00,  1.122800e+00,  7.300000e-04],
#        [-1.567630e+00, -5.715300e-01, -2.788100e-01],
#        [-1.956540e+00, -1.185550e+00, -9.450700e-01],
#        [-2.218750e+00, -2.414060e+00, -1.113300e-01],
#        [-2.839360e+00, -2.511470e+00,  6.970200e-01],
#        [-3.128170e+00, -1.648190e+00,  4.694800e-01],
#        [-2.508790e+00, -1.531010e+00,  1.114260e+00],
#        [-1.873050e+00, -1.379880e+00,  1.080570e+00],
#        [-1.402590e+00, -8.374000e-01,  6.926300e-01],
#        [-9.646000e-01, -4.306600e-01,  2.404800e-01],
#        [-6.176800e-01, -3.168900e-01, -6.590000e-03],
#        [-5.905800e-01, -1.926300e-01, -3.208000e-01],
#        [-6.525900e-01, -2.392600e-01, -3.830600e-01],
#        [-6.848100e-01, -8.081000e-02, -4.726600e-01],
#        [-7.529300e-01,  3.256800e-01, -6.086400e-01],
#        [-7.990700e-01,  7.172900e-01, -7.846700e-01]])]
# ['jumping', 'walking', 'jumping', 'running', 'jumping']
# ['f2ad', 'f2ad', 'f2ad', 'f2ad', 'f2ad']

# %% [markdown]
# ## Création d'un jeu de données de test et d'un jeu d'entrainement

# %% [markdown]
# Dans un premier temps, on va se charger de séparer nos données en un jeu d'entrainement et un jeu de test. Pour ce faire, on va séparer chacun des tests de chacun des individus en gardant 80 % des tests de chacun des individus comme des données d'entrainements et 20 % restants comme des données de test

# %%
from sklearn.model_selection import train_test_split
import numpy as np

unique_users = list(set(user_ids))

data_obs_train = []
data_obs_test = []
data_labels_train = []
data_labels_test = []
user_ids_train = []
user_ids_test = []

#Pour chaque utilisateur, on sépare les données en train et test
for user in unique_users:
    #Extraire les indices correspondant à l'utilisateur
    indices_user = [i for i, u_id in enumerate(user_ids) if u_id == user]

    #Diviser les indices en train et test
    indices_train, indices_test = train_test_split(indices_user, test_size=0.1, random_state=42)

    #Ajouter les données d'entrainements
    data_obs_train.extend([data_obs[i] for i in indices_train])
    data_labels_train.extend([data_labels[i] for i in indices_train])
    user_ids_train.extend([user_ids[i] for i in indices_train])

    #Ajouter les données de test
    data_obs_test.extend([data_obs[i] for i in indices_test])
    data_labels_test.extend([data_labels[i] for i in indices_test])
    user_ids_test.extend([user_ids[i] for i in indices_test])

# %% [markdown]
# ## Data Augmentation (méthode 1 d'ajustement du nombre de données)

# %%
data_obs_augment_train = data_obs_train
data_labels_augment_train = data_labels_train


# Fonction pour ajouter du jitter à chaque valeur d'accélération
def add_jitter_to_data(data, factor=0.05):
    jitter = factor * np.random.normal(size=data.shape)
    return data + jitter


#-----------------------------SITTING--------------------------------------------------------------

# Utiliser une liste en compréhension pour obtenir les indices avec le label "sitting"
indices_sitting = [i for i, label in enumerate(data_labels_augment_train) if label == "sitting"]

# Extraire les lignes associées au label "sitting" dans data_obs_train
data_obs_train_sitting = [data_obs_augment_train[i] for i in indices_sitting]
data_labels_train_sitting = [data_labels_augment_train[i] for i in indices_sitting]

# Créer un tableau pour stocker les données augmentées
augmented_data_sitting = []


# Appliquer la data augmentation jitter
for j in range(50): #Fais 10 fois un tour de boucle pour rajouter du random sur les 42 valeurs
  for i in range(len(data_obs_train_sitting)):
      augmented_data_sitting.append(add_jitter_to_data(data_obs_train_sitting[i]))

data_obs_augment_train.extend(augmented_data_sitting)
#print(augmented_data_sitting)

label_a_ajouter = "sitting"

# Ajouter 420 occurrences du label "sitting" à la fin de la liste
data_labels_augment_train.extend([label_a_ajouter] * len(augmented_data_sitting))


#----------------------------STANDING--------------------------------------------------------------

# Utiliser une liste en compréhension pour obtenir les indices avec le label "standing"
indices_standing = [i for i, label in enumerate(data_obs_augment_train) if label == "standing"]

# Extraire les lignes associées au label "sitting" dans data_obs_train
data_obs_train_standing = [data_obs_augment_train[i] for i in indices_standing]
data_labels_train_standing = [data_labels_augment_train[i] for i in indices_standing]

# Créer un tableau pour stocker les données augmentées
augmented_data_standing = []


# Appliquer la data augmentation jitter
for j in range(2): #Fais 10 fois un tour de boucle pour rajouter du random sur les 42 valeurs
  for i in range(len(data_obs_train_standing)):
      augmented_data_standing.append(add_jitter_to_data(data_obs_train_standing[i]))

data_obs_augment_train.extend(augmented_data_standing)
#print(augmented_data_sitting)

label_a_ajouter_2 = "standing"

# Ajouter 420 occurrences du label "sitting" à la fin de la liste
data_labels_augment_train.extend([label_a_ajouter_2] * len(augmented_data_standing))

#--------------------------------------------------------------------------------------------


# Utiliser un dictionnaire pour stocker le nombre d'occurrences de chaque label
occurrences = {}

# Compter le nombre d'occurrences pour chaque label
for label in data_labels_train:
    occurrences[label] = occurrences.get(label, 0) + 1

# Afficher le nombre d'occurrences pour chaque label
for label, count in occurrences.items():
    print(f"Label '{label}': {count} occurrence(s)")
# Out:
# Label 'walking': 3654 occurrence(s)
# Label 'jumping': 2199 occurrence(s)
# Label 'running': 3546 occurrence(s)
# Label 'standing': 947 occurrence(s)
# Label 'sitting': 2652 occurrence(s)
# <ipython-input-33-1acb83b2f5f2>:41: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   indices_standing = [i for i, label in enumerate(data_obs_augment_train) if label == "standing"]

# %% [markdown]
# ## Normalisation des données

# %%
#Normalisation des données classiques
from sklearn.preprocessing import StandardScaler

data_obs_train_concatenated = np.concatenate(data_obs_train)
data_obs_test_concatenated = np.concatenate(data_obs_test)

# Initialiser le scaler
scaler = StandardScaler()

# Adapter le scaler sur l'ensemble du jeu de données (entraînement + test)
scaler.fit(np.concatenate([data_obs_train_concatenated, data_obs_test_concatenated]))

# Appliquer la transformation sur toutes les séquences d'entraînement et de test
data_obs_train_Norm = [scaler.transform(obs) for obs in data_obs_train]
data_obs_test_Norm = [scaler.transform(obs) for obs in data_obs_test]




# Normalisation des DATA AUGMENTE


data_obs_augment_train_concatenated = np.concatenate(data_obs_augment_train)

# Initialiser le scaler
scaler = StandardScaler()

# Adapter le scaler sur l'ensemble du jeu de données (entraînement + test)
scaler.fit(np.concatenate([data_obs_augment_train_concatenated, data_obs_test_concatenated]))

# Appliquer la transformation sur toutes les séquences d'entraînement et de test
data_obs_augment_train_Norm = [scaler.transform(obs) for obs in data_obs_augment_train]
data_obs_augment_test_Norm = [scaler.transform(obs) for obs in data_obs_test]

# %% [markdown]
# ## Longueur de chaque série temporelle

# %% [markdown]
# Analyse du nombre de classes de y dans le jeu de test et dans le jeu d'apprentissage :

# %%
print('Il y a ', len(np.unique(data_labels_train)), ' classes dans les données d\'entraînement')
print('Il y a ', len(np.unique(data_labels_test)), ' classes dans les données de test')
print('Il y a ', len(np.unique(data_labels)), ' classes dans les données totales')


print('dif label en entrainement : ', np.unique(data_labels_train))
print('dif label en test : ',np.unique(data_labels_test))
print('dif label au total : ',np.unique(data_labels))
# Out:
# Il y a  5  classes dans les données d'entraînement
# Il y a  5  classes dans les données de test
# Il y a  5  classes dans les données totales
# dif label en entrainement :  ['jumping' 'running' 'sitting' 'standing' 'walking']
# dif label en test :  ['jumping' 'running' 'sitting' 'standing' 'walking']
# dif label au total :  ['jumping' 'running' 'sitting' 'standing' 'walking']

# %% [markdown]
# *Les labels sont bien les mêmes dans les jeux d'entrainements et de tests et correspondent bien à ceux du jeu de base*
#
#
# Dans notre cas, il serait préférables d'avoir des séquences de tailles identiques ( plus simple pour la convergence des informations)
# On va donc chercher à rajouter du padding (séries de 0 pour complémenter le manque d elongueur sur certaines séquences) ou a réaliser du troncage (garder uniquement la partie la plus importante de chaque série pour obtenir des informations de même taille)

# %%
num_sequences = len(data_obs_train_Norm)

# Afficher la longueur de chaque séquence
for i in range(min(5,num_sequences)):
    print(f"Longueur de la séquence {i + 1}: {len(data_obs_train[i])}")
# Out:
# Longueur de la séquence 1: 196
# Longueur de la séquence 2: 30
# Longueur de la séquence 3: 2035
# Longueur de la séquence 4: 69
# Longueur de la séquence 5: 471

# %% [markdown]
# On voit ici que les séquences sont très variables. On va donc analyser la densité de chaque longueur de séquences afin d'obtenir des informations sur les données que l'on possède. Par la suite nous réaliserons le padding ou le troncage pour obtenir des longueurs de séries temporelles identiques.

# %% [markdown]
# #### Jeu de données d'entrainement

# %%
import matplotlib.pyplot as plt

# Calculer la longueur de chaque séquence
sequence_lengths = [len(seq) for seq in data_obs_train_Norm]

bins = np.arange(0, 1000, 50)
# Afficher un histogramme
plt.hist(sequence_lengths, bins=bins, edgecolor='black')
plt.title('Distribution des longueurs des séquences pour le jeu d\'entrainements')
plt.xlabel('Longueur de la séquence')
plt.ylabel('Fréquence')
plt.show()

min_length = min(sequence_lengths)
max_length = max(sequence_lengths)
mean_length = np.mean(sequence_lengths)

print(f"Longueur minimale : {min_length}")
print(f"Longueur maximale : {max_length}")
print(f"Longueur moyenne : {mean_length}")
# Out:
# Longueur minimale : 1
# Longueur maximale : 46004
# Longueur moyenne : 2091.704877673488

# %% [markdown]
# #### Jeu de données de test

# %%
import matplotlib.pyplot as plt

# Calculer la longueur de chaque séquence
sequence_lengths = [len(seq) for seq in data_obs_test]

bins = np.arange(0, 1000, 50)
# Afficher un histogramme
plt.hist(sequence_lengths, bins=bins, edgecolor='black')
plt.title('Distribution des longueurs des séquences pour le jeu de test')
plt.xlabel('Longueur de la séquence')
plt.ylabel('Fréquence')
plt.show()

min_length = min(sequence_lengths)
max_length = max(sequence_lengths)
mean_length = np.mean(sequence_lengths)

print(f"Longueur minimale : {min_length}")
print(f"Longueur maximale : {max_length}")
print(f"Longueur moyenne : {mean_length}")
# Out:
# Longueur minimale : 9
# Longueur maximale : 11785
# Longueur moyenne : 431.65606190885643

# %% [markdown]
# ## Padding

# %% [markdown]
# Test avec padding = 2100 car moyenne du jeu de données d'entrainements

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

data_obs_train_Norm_pad = []
data_obs_train_Norm_pad = pad_sequences(data_obs_train_Norm, maxlen=600, padding='post', dtype='float32')

data_obs_test_Norm_pad = []
data_obs_test_Norm_pad = pad_sequences(data_obs_test_Norm, maxlen=600, padding='post', dtype='float32')

#Padding DATA AUGMENTE

data_obs_augment_train_Norm_pad = []
data_obs_augment_train_Norm_pad = pad_sequences(data_obs_augment_train_Norm, maxlen=2000, padding='post', dtype='float32')

data_obs_augment_test_Norm_pad = []
data_obs_augment_test_Norm_pad = pad_sequences(data_obs_augment_test_Norm, maxlen=2000, padding='post', dtype='float32')

# %% [markdown]
# ## Encodage des labels

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

#Encoder les labels en entiers
labels_encoder = LabelEncoder()
labels_train_int = labels_encoder.fit_transform(data_labels_train)
labels_test_int = labels_encoder.fit_transform(data_labels_test)

#Encoder les labels en one-hot
labels_onehot = OneHotEncoder(sparse=False, categories='auto')
labels_train_onehot = labels_onehot.fit_transform(labels_train_int.reshape(-1, 1))
labels_test_onehot = labels_onehot.fit_transform(labels_test_int.reshape(-1, 1))


# ENCODAGE DES LABELS DATA AUGMENTE

labels_augment_train_int = labels_encoder.fit_transform(data_labels_augment_train)

labels_augment_train_onehot = labels_onehot.fit_transform(labels_augment_train_int.reshape(-1, 1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## Attribution de poids aux variables (méthode 2 d'ajustement du nombre de données)

# %% [markdown]
# Configurer l'attribution de poids pour la comparaison entre ajout de poids ou data augmentation

# %%
def get_custom_sample_weight(y):
    """Return custom sample weights."""
    y = np.asarray(y)

    # Définir les poids personnalisés pour chaque classe
    class_weights = {0: 1.0, 1: 1.0, 2: 10.0, 3: 10.0, 4: 1.0}  # Modifiez selon vos besoins

    sample_weight = []

    for label in y:
        idx, *__ = np.where(label == 1)
        sample_weight += [max([class_weights[i] for i in idx])]

    return np.array(sample_weight)

# Utilisation de la fonction pour obtenir les poids personnalisés
custom_sample_weights = get_custom_sample_weight(labels_train_onehot)

# Convertir les étiquettes one-hot en noms d'étiquettes
class_labels = ['jumping', 'running', 'sitting', 'standing', 'walking']
predicted_labels = [class_labels[np.argmax(label)] for label in labels_train_onehot]

# Convertir les étiquettes one-hot en indices de classe
class_indices = np.argmax(labels_train_onehot, axis=1)

# Initialiser un dictionnaire pour stocker un exemple pour chaque classe
examples_by_class = {class_label: None for class_label in set(class_indices)}

# Parcourir les exemples et remplir le dictionnaire
for i, class_index in enumerate(class_indices):
    if examples_by_class[class_index] is None:
        examples_by_class[class_index] = i

# Afficher un exemple pour chaque classe
for class_label, example_index in examples_by_class.items():
    print(f"Classe {class_label}: Poids = {custom_sample_weights[example_index]}")
    print(f"   Exemple {example_index + 1} : {labels_train_onehot[example_index]}")
    print(f"   Label: {predicted_labels[example_index]}")
# Out:
# Classe 0: Poids = 1.0
#    Exemple 2 : [1. 0. 0. 0. 0.]
#    Label: jumping
# Classe 1: Poids = 1.0
#    Exemple 4 : [0. 1. 0. 0. 0.]
#    Label: running
# Classe 2: Poids = 10.0
#    Exemple 52 : [0. 0. 1. 0. 0.]
#    Label: sitting
# Classe 3: Poids = 10.0
#    Exemple 16 : [0. 0. 0. 1. 0.]
#    Label: standing
# Classe 4: Poids = 1.0
#    Exemple 1 : [0. 0. 0. 0. 1.]
#    Label: walking

# %% [markdown]
# Pour être sur de ne pas se tromper on va créer les deux manières et on comparera pour chacun des test les deux manières de faire

# %% [markdown]
# ## Comparaison des modèles

# %% [markdown]
# ### Réseau RNN 1 couche

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import SimpleRNN, Dense, Flatten, Input
from keras.callbacks import EarlyStopping

cb = EarlyStopping(monitor='val_loss',patience=3, min_delta=0.01, restore_best_weights=True, verbose=2)


def model_rnn_basique(T, D, nb_classes):
  input = Input(shape = (T, D))
  Couche_rec = SimpleRNN(64)(input)
  dense1 = Dense(nb_classes, activation = "sigmoid")(Couche_rec)
  model = Model(inputs=input, outputs=dense1)
  model.compile(optimizer = 'adam', loss = 'categorical_crossentropy',metrics=["accuracy"])
  model.summary()
  return model

# %%
model_rnn = model_rnn_basique(600, 3, 5)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 600, 3)]          0
#
#  simple_rnn_1 (SimpleRNN)    (None, 64)                4352
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 4677 (18.27 KB)
# Trainable params: 4677 (18.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Test data classique (utilisation de la data augmentée mais padding en utilisant un peu plus que la moyenne des observations sans data augmentée (car on rajoute beaucoup de sitting qui sont globalement des très longues périodes)

# %%
history_rnn_simple = model_rnn.fit(data_obs_train_Norm_pad, labels_train_onehot, epochs=10, batch_size=256, validation_data=(data_obs_test_Norm_pad, labels_test_onehot),  callbacks=[cb])
# Out:
# Epoch 1/10
# 51/51 [==============================] - 32s 412ms/step - loss: 1.4150 - accuracy: 0.3851 - val_loss: 1.3659 - val_accuracy: 0.3663
# Epoch 2/10
# 51/51 [==============================] - 19s 378ms/step - loss: 1.3059 - accuracy: 0.4240 - val_loss: 1.3585 - val_accuracy: 0.3637
# Epoch 3/10
# 51/51 [==============================] - 19s 367ms/step - loss: 1.2090 - accuracy: 0.4610 - val_loss: 1.3482 - val_accuracy: 0.3715
# Epoch 4/10
# 51/51 [==============================] - 20s 399ms/step - loss: 1.1901 - accuracy: 0.4685 - val_loss: 1.3509 - val_accuracy: 0.3654
# Epoch 5/10
# 51/51 [==============================] - 19s 373ms/step - loss: 1.1760 - accuracy: 0.4724 - val_loss: 1.3372 - val_accuracy: 0.3783
# Epoch 6/10
# 51/51 [==============================] - 20s 391ms/step - loss: 1.2394 - accuracy: 0.4381 - val_loss: 1.3519 - val_accuracy: 0.3723
# Epoch 7/10
# 51/51 [==============================] - 26s 506ms/step - loss: 1.1694 - accuracy: 0.4795 - val_loss: 1.3309 - val_accuracy: 0.3852
# Epoch 8/10
# 51/51 [==============================] - 20s 397ms/step - loss: 1.1498 - accuracy: 0.4851 - val_loss: 1.3232 - val_accuracy: 0.3809
# Epoch 9/10
# 51/51 [==============================] - 19s 365ms/step - loss: 1.1359 - accuracy: 0.4943 - val_loss: 1.3154 - val_accuracy: 0.3826
# Epoch 10/10
# 51/51 [==============================] - 19s 369ms/step - loss: 1.1275 - accuracy: 0.4991 - val_loss: 1.3000 - val_accuracy: 0.4033

# %% [markdown]
# Avec data augmentée

# %%
model_rnn = model_rnn_basique(2000, 3, 5)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 2000, 3)]         0
#
#  simple_rnn_4 (SimpleRNN)    (None, 64)                4352
#
#  dense_4 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 4677 (18.27 KB)
# Trainable params: 4677 (18.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history_rnn_data_augment = model_rnn.fit(data_obs_augment_train_Norm_pad, labels_augment_train_onehot, epochs=10, batch_size=256, validation_data=(data_obs_test_Norm_pad, labels_test_onehot),  callbacks=[cb])
# Out:
# Epoch 1/10
# 51/51 [==============================] - ETA: 0s - loss: 1.4645 - accuracy: 0.3318
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-0b617c524953> in <cell line: 1>()
# ----> 1 history_rnn_data_augment = model_rnn.fit(data_obs_augment_train_Norm_pad, labels_augment_train_onehot, epochs=10, batch_size=256, validation_data=(data_obs_test_Norm_pad, labels_test_onehot),  callbacks=[cb])
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__test_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2042, in test_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2025, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2013, in run_step  **
#         outputs = model.test_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1893, in test_step
#         y_pred = self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "model_4" is incompatible with the layer: expected shape=(None, 2000, 3), found shape=(None, 600, 3)

# %% [markdown]
# Avec poids

# %%
history_rnn_poids = model_rnn.fit(data_obs_train_Norm_pad, labels_train_onehot, epochs=10, batch_size=256, validation_data=(data_obs_test_Norm_pad, labels_test_onehot),sample_weight=custom_sample_weights,  callbacks=[cb])
# Out:
# Epoch 1/10
# 51/51 [==============================] - 19s 365ms/step - loss: 4.6351 - accuracy: 0.2033 - val_loss: 2.0272 - val_accuracy: 0.0120
# Epoch 2/10
# 51/51 [==============================] - 19s 368ms/step - loss: 3.9502 - accuracy: 0.2062 - val_loss: 2.2279 - val_accuracy: 0.0095
# Epoch 3/10
# 51/51 [==============================] - 20s 399ms/step - loss: 3.5443 - accuracy: 0.2204 - val_loss: 2.1825 - val_accuracy: 0.0430
# Epoch 4/10
# 51/51 [==============================] - ETA: 0s - loss: 3.2302 - accuracy: 0.2400Restoring model weights from the end of the best epoch: 1.
# 51/51 [==============================] - 19s 375ms/step - loss: 3.2302 - accuracy: 0.2400 - val_loss: 2.8317 - val_accuracy: 0.0292
# Epoch 4: early stopping

# %% [markdown]
# Comparaison des 3 modalités

# %%
# Visualiser l'évolution de la perte et de la précision au fil des épochs
import matplotlib.pyplot as plt

plt.subplot(1, 2, 1)
plt.plot(history_rnn_simple.history['val_loss'], label='RNN simple')
plt.plot(history_rnn_data_augment.history['val_loss'], label='RNN avec data augmentée')
plt.plot(history_rnn_poids.history['val_loss'], label='RNN simple avec attribution de poids')
plt.title('Validation Perte')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_rnn_simple.history['val_accuracy'])
plt.plot(history_rnn_data_augment.history['val_accuracy'])
plt.plot(history_rnn_poids.history['val_accuracy'])
plt.title('Validation Accuracy')
plt.legend()

# Ajuster l'espacement entre les sous-graphiques
plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **Ici on voit donc bien que les meilleures résultats sont ceux qui utilisent les données de data augmentées tout en conservant les valeurs de padding à 600**

# %% [markdown]
# ### Réseau RNN 2 couche

# %%
def model_rnn_avance(T, D, nb_classes):
  input = Input(shape = (T, D))
  Couche_rec = SimpleRNN(64, return_sequences=True)(input)
  Couche_rec2 = SimpleRNN(32)(Couche_rec)
  dense1 = Dense(nb_classes, activation = "sigmoid")(Couche_rec2)
  model = Model(inputs=input, outputs=dense1)
  model.compile(optimizer = 'adam', loss = 'categorical_crossentropy',metrics=["accuracy"])
  model.summary()
  return model

# %%
model_rnn_avance = model_rnn_avance(600, 3, 5)
history_rnn_avance = model_rnn_avance.fit(data_obs_train_Norm_pad, labels_train_onehot, epochs=10, batch_size=500, validation_data=(data_obs_test_Norm_pad, labels_test_onehot),  callbacks=[cb])
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 600, 3)]          0
#
#  simple_rnn_5 (SimpleRNN)    (None, 600, 64)           4352
#
#  simple_rnn_6 (SimpleRNN)    (None, 32)                3104
#
#  dense_5 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 7621 (29.77 KB)
# Trainable params: 7621 (29.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 26/26 [==============================] - 35s 1s/step - loss: 1.4329 - accuracy: 0.3412 - val_loss: 1.3837 - val_accuracy: 0.3637
# Epoch 2/10
# 26/26 [==============================] - 29s 1s/step - loss: 1.2368 - accuracy: 0.4557 - val_loss: 1.3960 - val_accuracy: 0.3259
# Epoch 3/10
# 26/26 [==============================] - 28s 1s/step - loss: 1.1944 - accuracy: 0.4658 - val_loss: 1.3589 - val_accuracy: 0.3646
# Epoch 4/10
# 26/26 [==============================] - 28s 1s/step - loss: 1.1626 - accuracy: 0.4762 - val_loss: 1.3351 - val_accuracy: 0.3835
# Epoch 5/10
# 26/26 [==============================] - 28s 1s/step - loss: 1.1409 - accuracy: 0.4856 - val_loss: 1.3275 - val_accuracy: 0.3887
# Epoch 6/10
# 26/26 [==============================] - 27s 1s/step - loss: 1.1254 - accuracy: 0.4963 - val_loss: 1.3123 - val_accuracy: 0.3938
# Epoch 7/10
# 26/26 [==============================] - 28s 1s/step - loss: 1.1115 - accuracy: 0.5031 - val_loss: 1.3053 - val_accuracy: 0.3990
# Epoch 8/10
# 26/26 [==============================] - 27s 1s/step - loss: 1.1006 - accuracy: 0.5088 - val_loss: 1.2818 - val_accuracy: 0.4162
# Epoch 9/10
# 26/26 [==============================] - 28s 1s/step - loss: 1.0816 - accuracy: 0.5188 - val_loss: 1.2770 - val_accuracy: 0.4144
# Epoch 10/10
# 26/26 [==============================] - 28s 1s/step - loss: 1.1185 - accuracy: 0.5115 - val_loss: 1.3091 - val_accuracy: 0.4110

# %% [markdown]
# ### Modèle LTSM

# %%
# Definition du modèle
from tensorflow.keras.layers import Input, Dense, SimpleRNN, LSTM, Flatten
def model_lstm(T, D, nb_classes):
  input = Input(shape = (T, D))
  Couche_rec = LSTM(64, return_sequences=True)(input)
  Couche_rec2 = LSTM(32)(Couche_rec)
  dense1 = Dense(nb_classes, activation = "sigmoid")(Couche_rec2)
  model = Model(inputs=input, outputs=dense1)
  model.compile(optimizer = 'adam', loss = 'categorical_crossentropy',metrics=["accuracy"])
  model.summary()
  return model

# %%
model_lstm = model_lstm(600, 3, 5)
history_lstm = model_lstm.fit(data_obs_train_Norm_pad, labels_train_onehot, epochs=10, batch_size=500, validation_data=(data_obs_test_Norm_pad, labels_test_onehot),  callbacks=[cb])
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 600, 3)]          0
#
#  lstm (LSTM)                 (None, 600, 64)           17408
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dense_6 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 29989 (117.14 KB)
# Trainable params: 29989 (117.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 26/26 [==============================] - 70s 120ms/step - loss: 1.4891 - accuracy: 0.3841 - val_loss: 1.4004 - val_accuracy: 0.3947
# Epoch 2/10
# 26/26 [==============================] - 2s 76ms/step - loss: 1.2273 - accuracy: 0.4600 - val_loss: 1.3086 - val_accuracy: 0.4101
# Epoch 3/10
# 26/26 [==============================] - 2s 75ms/step - loss: 1.1478 - accuracy: 0.4959 - val_loss: 1.3694 - val_accuracy: 0.3637
# Epoch 4/10
# 26/26 [==============================] - 2s 76ms/step - loss: 1.1462 - accuracy: 0.5046 - val_loss: 1.2689 - val_accuracy: 0.4291
# Epoch 5/10
# 26/26 [==============================] - 2s 78ms/step - loss: 1.0960 - accuracy: 0.5166 - val_loss: 1.2770 - val_accuracy: 0.4248
# Epoch 6/10
# 26/26 [==============================] - 2s 79ms/step - loss: 1.0818 - accuracy: 0.5198 - val_loss: 1.2207 - val_accuracy: 0.4445
# Epoch 7/10
# 26/26 [==============================] - 2s 76ms/step - loss: 1.0821 - accuracy: 0.5188 - val_loss: 1.2397 - val_accuracy: 0.4325
# Epoch 8/10
# 26/26 [==============================] - 2s 80ms/step - loss: 1.0763 - accuracy: 0.5152 - val_loss: 1.2276 - val_accuracy: 0.4248
# Epoch 9/10
# 26/26 [==============================] - ETA: 0s - loss: 1.0867 - accuracy: 0.5057Restoring model weights from the end of the best epoch: 6.
# 26/26 [==============================] - 2s 77ms/step - loss: 1.0867 - accuracy: 0.5057 - val_loss: 1.2659 - val_accuracy: 0.4265
# Epoch 9: early stopping

# %% [markdown]
# ### LSTM Bidirectionnal

# %%
# Definition du modèle
from tensorflow.keras.layers import Input, Dense, SimpleRNN, LSTM, Flatten, Bidirectional
def model_lstm_bidi(T, D, nb_classes):
  input = Input(shape = (T, D))
  Couche_rec = Bidirectional(LSTM(128, return_sequences=True))(input)
  Couche_rec2 = Bidirectional(LSTM(128, return_sequences = True))(Couche_rec)
  Couche_rec3 = Bidirectional(LSTM(64, return_sequences = True))(Couche_rec2)
  Couche_rec4 = Bidirectional(LSTM(64, return_sequences = True))(Couche_rec3)
  Flatten1 = Flatten()(Couche_rec4)
  dense1 = Dense(32, activation = "relu")(Flatten1)
  dense2 = Dense(nb_classes, activation = "softmax")(dense1)
  model = Model(inputs=input, outputs=dense2)
  model.compile(optimizer = 'adam', loss = 'categorical_crossentropy',metrics=["accuracy"])
  model.summary()
  return model

# %%
model_lstm_bidi = model_lstm_bidi(600, 3, 5)
history_lstm_bidi = model_lstm_bidi.fit(data_obs_train_Norm_pad, labels_train_onehot, epochs=20, batch_size=256, validation_data=(data_obs_test_Norm_pad, labels_test_onehot))
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 600, 3)]          0
#
#  bidirectional_4 (Bidirecti  (None, 600, 256)          135168
#  onal)
#
#  bidirectional_5 (Bidirecti  (None, 600, 256)          394240
#  onal)
#
#  bidirectional_6 (Bidirecti  (None, 600, 128)          164352
#  onal)
#
#  bidirectional_7 (Bidirecti  (None, 600, 128)          98816
#  onal)
#
#  flatten_12 (Flatten)        (None, 76800)             0
#
#  dense_22 (Dense)            (None, 32)                2457632
#
#  dense_23 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 3250373 (12.40 MB)
# Trainable params: 3250373 (12.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 51/51 [==============================] - 43s 512ms/step - loss: 0.6472 - accuracy: 0.7694 - val_loss: 0.4817 - val_accuracy: 0.8108
# Epoch 2/20
# 51/51 [==============================] - 23s 459ms/step - loss: 0.3981 - accuracy: 0.8557 - val_loss: 0.4333 - val_accuracy: 0.8315
# Epoch 3/20
# 51/51 [==============================] - 23s 450ms/step - loss: 0.3570 - accuracy: 0.8657 - val_loss: 0.4249 - val_accuracy: 0.8340
# Epoch 4/20
# 51/51 [==============================] - 24s 462ms/step - loss: 0.3231 - accuracy: 0.8758 - val_loss: 0.4174 - val_accuracy: 0.8426
# Epoch 5/20
# 51/51 [==============================] - 23s 456ms/step - loss: 0.2877 - accuracy: 0.8908 - val_loss: 0.3956 - val_accuracy: 0.8375
# Epoch 6/20
# 51/51 [==============================] - 23s 448ms/step - loss: 0.2422 - accuracy: 0.9111 - val_loss: 0.3852 - val_accuracy: 0.8564
# Epoch 7/20
# 51/51 [==============================] - 23s 445ms/step - loss: 0.2152 - accuracy: 0.9200 - val_loss: 0.3969 - val_accuracy: 0.8624
# Epoch 8/20
# 51/51 [==============================] - 23s 442ms/step - loss: 0.1936 - accuracy: 0.9284 - val_loss: 0.3738 - val_accuracy: 0.8702
# Epoch 9/20
# 51/51 [==============================] - 23s 445ms/step - loss: 0.1548 - accuracy: 0.9431 - val_loss: 0.4282 - val_accuracy: 0.8521
# Epoch 10/20
# 51/51 [==============================] - 23s 456ms/step - loss: 0.1321 - accuracy: 0.9506 - val_loss: 0.4571 - val_accuracy: 0.8530
# Epoch 11/20
# 51/51 [==============================] - 23s 446ms/step - loss: 0.0995 - accuracy: 0.9635 - val_loss: 0.4749 - val_accuracy: 0.8676
# Epoch 12/20
# 51/51 [==============================] - 23s 446ms/step - loss: 0.0947 - accuracy: 0.9667 - val_loss: 0.5191 - val_accuracy: 0.8564
# Epoch 13/20
# 51/51 [==============================] - 23s 446ms/step - loss: 0.0692 - accuracy: 0.9753 - val_loss: 0.5342 - val_accuracy: 0.8547
# Epoch 14/20
# 51/51 [==============================] - 23s 455ms/step - loss: 0.0524 - accuracy: 0.9825 - val_loss: 0.5799 - val_accuracy: 0.8736
# Epoch 15/20
# 51/51 [==============================] - 23s 455ms/step - loss: 0.0432 - accuracy: 0.9853 - val_loss: 0.6360 - val_accuracy: 0.8659
# Epoch 16/20
# 51/51 [==============================] - 23s 455ms/step - loss: 0.0429 - accuracy: 0.9862 - val_loss: 0.6015 - val_accuracy: 0.8788
# Epoch 17/20
# 51/51 [==============================] - 23s 446ms/step - loss: 0.0514 - accuracy: 0.9808 - val_loss: 0.6087 - val_accuracy: 0.8598
# Epoch 18/20
# 51/51 [==============================] - 23s 446ms/step - loss: 0.0772 - accuracy: 0.9729 - val_loss: 0.7038 - val_accuracy: 0.8530
# Epoch 19/20
# 51/51 [==============================] - 23s 445ms/step - loss: 0.1407 - accuracy: 0.9588 - val_loss: 0.6629 - val_accuracy: 0.8573
# Epoch 20/20
# 51/51 [==============================] - 23s 445ms/step - loss: 0.0762 - accuracy: 0.9748 - val_loss: 0.6955 - val_accuracy: 0.8676

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# ...

# Après l'entraînement du modèle
y_pred = model_lstm_bidi.predict(data_obs_test_Norm_pad)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(labels_test_onehot, axis=1)

# Calcul de la matrice de confusion
conf_matrix = confusion_matrix(y_true, y_pred_classes)

class_names = np.unique(data_labels)


# Affichage de la matrice de confusion
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Matrice de Confusion')
plt.xlabel('Classe Prédite')
plt.ylabel('Classe Réelle')
plt.show()

# Calcul et affichage de la précision globale
accuracy = accuracy_score(y_true, y_pred_classes)
print(f"Précision globale : {accuracy * 100:.2f}%")
# Out:
# 37/37 [==============================] - 5s 62ms/step
# Précision globale : 86.76%

# %% [markdown]
# Les résultats commencent à devebir intéressant avec ce modèle

# %% [markdown]
# ### LTSM avancée

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Flatten, Dropout

def lstm_avance(T, D, nb_classes):
  model = Sequential()
  model.add(LSTM(units = 128, input_shape = (T, D)))
      # Dropout layer
  model.add(Dropout(0.5))
# Dense layer with ReLu
  model.add(Dense(units = 64, activation='relu'))
# Softmax layer
  model.add(Dense(nb_classes, activation = 'softmax'))
# Compile model
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  model.summary()
  return model

# %%
lstm_avance = lstm_avance(600, 3, 5)
history_lstm_avancee = lstm_avance.fit(data_obs_train_Norm_pad, labels_train_onehot, epochs=10, batch_size=500, validation_data=(data_obs_test_Norm_pad, labels_test_onehot),  callbacks=[cb])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 128)               67584
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_9 (Dense)             (None, 64)                8256
#
#  dense_10 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 76165 (297.52 KB)
# Trainable params: 76165 (297.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 26/26 [==============================] - 7s 115ms/step - loss: 1.4712 - accuracy: 0.4032 - val_loss: 1.4974 - val_accuracy: 0.3646
# Epoch 2/10
# 26/26 [==============================] - 2s 89ms/step - loss: 1.3721 - accuracy: 0.4287 - val_loss: 1.4169 - val_accuracy: 0.3586
# Epoch 3/10
# 26/26 [==============================] - 2s 88ms/step - loss: 1.2300 - accuracy: 0.4642 - val_loss: 1.3508 - val_accuracy: 0.3835
# Epoch 4/10
# 26/26 [==============================] - 2s 85ms/step - loss: 1.1524 - accuracy: 0.4903 - val_loss: 1.2937 - val_accuracy: 0.4076
# Epoch 5/10
# 26/26 [==============================] - 2s 85ms/step - loss: 1.1386 - accuracy: 0.4978 - val_loss: 1.3248 - val_accuracy: 0.3887
# Epoch 6/10
# 26/26 [==============================] - 2s 86ms/step - loss: 1.1636 - accuracy: 0.4848 - val_loss: 1.3088 - val_accuracy: 0.4024
# Epoch 7/10
# 26/26 [==============================] - ETA: 0s - loss: 1.3056 - accuracy: 0.4345Restoring model weights from the end of the best epoch: 4.
# 26/26 [==============================] - 2s 87ms/step - loss: 1.3056 - accuracy: 0.4345 - val_loss: 1.3044 - val_accuracy: 0.4394
# Epoch 7: early stopping

# %% [markdown]
# ### CNN

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from tensorflow.keras.layers import Input, Dense, SimpleRNN, LSTM, Flatten, Bidirectional, InputLayer, Conv2D, MaxPool2D, Masking
from tensorflow.keras.models import Sequential, Model
from keras.callbacks import EarlyStopping


cb = EarlyStopping(monitor='val_accuracy',patience=5, min_delta=0.2, restore_best_weights=True, verbose=2)

def cnn_model(T, D, nb_classes):
  model = Sequential([
      InputLayer(input_shape = (T, D, 1)),
      Conv2D(filters=196, kernel_size= (12, 1), strides=1, padding='same', activation='relu'),
      MaxPool2D(pool_size=(1, 4), strides=1, padding='same'),
      Flatten(),
      Dense(units=nb_classes, activation='softmax')
  ])
  model.compile(optimizer = 'adam', loss = 'categorical_crossentropy',metrics=["accuracy"])
  model.summary()
  return model

# %% [markdown]
# Execution sans poids mais avec data augmentation

# %%
model_cnn = cnn_model(600, 3, 5)
history_cnn = model_cnn.fit(data_obs_train_Norm_pad, labels_train_onehot, epochs=20, batch_size=256, validation_data=(data_obs_test_Norm_pad, labels_test_onehot))
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 600, 3, 196)       2548
#
#  max_pooling2d_7 (MaxPoolin  (None, 600, 3, 196)       0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 352800)            0
#
#  dense_18 (Dense)            (None, 5)                 1764005
#
# =================================================================
# Total params: 1766553 (6.74 MB)
# Trainable params: 1766553 (6.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 51/51 [==============================] - 4s 56ms/step - loss: 1.4098 - accuracy: 0.7255 - val_loss: 0.5544 - val_accuracy: 0.8151
# Epoch 2/20
# 51/51 [==============================] - 3s 53ms/step - loss: 0.3977 - accuracy: 0.8624 - val_loss: 0.5090 - val_accuracy: 0.8315
# Epoch 3/20
# 51/51 [==============================] - 3s 55ms/step - loss: 0.3381 - accuracy: 0.8772 - val_loss: 0.5006 - val_accuracy: 0.8151
# Epoch 4/20
# 51/51 [==============================] - 3s 52ms/step - loss: 0.3088 - accuracy: 0.8898 - val_loss: 0.5152 - val_accuracy: 0.8349
# Epoch 5/20
# 51/51 [==============================] - 3s 53ms/step - loss: 0.2724 - accuracy: 0.8994 - val_loss: 0.5069 - val_accuracy: 0.8366
# Epoch 6/20
# 51/51 [==============================] - 3s 53ms/step - loss: 0.2465 - accuracy: 0.9073 - val_loss: 0.5325 - val_accuracy: 0.8323
# Epoch 7/20
# 51/51 [==============================] - 3s 53ms/step - loss: 0.2247 - accuracy: 0.9184 - val_loss: 0.5261 - val_accuracy: 0.8332
# Epoch 8/20
# 51/51 [==============================] - 3s 56ms/step - loss: 0.2070 - accuracy: 0.9238 - val_loss: 0.5008 - val_accuracy: 0.8418
# Epoch 9/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.1987 - accuracy: 0.9258 - val_loss: 0.5391 - val_accuracy: 0.8340
# Epoch 10/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.1837 - accuracy: 0.9285 - val_loss: 0.5337 - val_accuracy: 0.8375
# Epoch 11/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.1792 - accuracy: 0.9325 - val_loss: 0.7704 - val_accuracy: 0.7979
# Epoch 12/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.1713 - accuracy: 0.9366 - val_loss: 0.6735 - val_accuracy: 0.8272
# Epoch 13/20
# 51/51 [==============================] - 3s 56ms/step - loss: 0.1727 - accuracy: 0.9350 - val_loss: 0.5985 - val_accuracy: 0.8452
# Epoch 14/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.1613 - accuracy: 0.9412 - val_loss: 0.6269 - val_accuracy: 0.8212
# Epoch 15/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.1436 - accuracy: 0.9478 - val_loss: 0.6971 - val_accuracy: 0.8229
# Epoch 16/20
# 51/51 [==============================] - 3s 53ms/step - loss: 0.1249 - accuracy: 0.9542 - val_loss: 0.6121 - val_accuracy: 0.8375
# Epoch 17/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.1168 - accuracy: 0.9582 - val_loss: 0.6473 - val_accuracy: 0.8418
# Epoch 18/20
# 51/51 [==============================] - 3s 56ms/step - loss: 0.1238 - accuracy: 0.9556 - val_loss: 0.6604 - val_accuracy: 0.8504
# Epoch 19/20
# 51/51 [==============================] - 3s 53ms/step - loss: 0.1131 - accuracy: 0.9610 - val_loss: 0.8293 - val_accuracy: 0.8255
# Epoch 20/20
# 51/51 [==============================] - 3s 53ms/step - loss: 0.1654 - accuracy: 0.9404 - val_loss: 0.8497 - val_accuracy: 0.8117

# %% [markdown]
# Execution avec poids et sans data augmentation

# %%
model_cnn_poids = cnn_model(600, 3, 5)
history_cnn_poids = model_cnn_poids.fit(data_obs_train_Norm_pad, labels_train_onehot,
                             epochs=20, batch_size=256,
                             validation_data=(data_obs_test_Norm_pad, labels_test_onehot),
                             sample_weight=custom_sample_weights)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 600, 3, 196)       2548
#
#  max_pooling2d_10 (MaxPooli  (None, 600, 3, 196)       0
#  ng2D)
#
#  flatten_11 (Flatten)        (None, 352800)            0
#
#  dense_21 (Dense)            (None, 5)                 1764005
#
# =================================================================
# Total params: 1766553 (6.74 MB)
# Trainable params: 1766553 (6.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 51/51 [==============================] - 4s 57ms/step - loss: 4.2107 - accuracy: 0.6093 - val_loss: 1.2578 - val_accuracy: 0.5408
# Epoch 2/20
# 51/51 [==============================] - 3s 53ms/step - loss: 1.2761 - accuracy: 0.7461 - val_loss: 1.0720 - val_accuracy: 0.6045
# Epoch 3/20
# 51/51 [==============================] - 3s 54ms/step - loss: 1.0143 - accuracy: 0.7843 - val_loss: 1.0704 - val_accuracy: 0.6045
# Epoch 4/20
# 51/51 [==============================] - 3s 55ms/step - loss: 0.7875 - accuracy: 0.8199 - val_loss: 0.6509 - val_accuracy: 0.7661
# Epoch 5/20
# 51/51 [==============================] - 3s 56ms/step - loss: 0.7043 - accuracy: 0.8362 - val_loss: 0.6126 - val_accuracy: 0.7902
# Epoch 6/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.7107 - accuracy: 0.8427 - val_loss: 0.8413 - val_accuracy: 0.7068
# Epoch 7/20
# 51/51 [==============================] - 3s 53ms/step - loss: 0.6254 - accuracy: 0.8573 - val_loss: 0.6264 - val_accuracy: 0.7859
# Epoch 8/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.5378 - accuracy: 0.8737 - val_loss: 0.6483 - val_accuracy: 0.7859
# Epoch 9/20
# 51/51 [==============================] - 3s 55ms/step - loss: 0.5585 - accuracy: 0.8752 - val_loss: 0.7652 - val_accuracy: 0.7558
# Epoch 10/20
# 51/51 [==============================] - 3s 56ms/step - loss: 0.4430 - accuracy: 0.8905 - val_loss: 0.6392 - val_accuracy: 0.8040
# Epoch 11/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.4003 - accuracy: 0.8961 - val_loss: 0.7029 - val_accuracy: 0.7747
# Epoch 12/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.3809 - accuracy: 0.8980 - val_loss: 0.7069 - val_accuracy: 0.7962
# Epoch 13/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.3678 - accuracy: 0.9018 - val_loss: 0.7280 - val_accuracy: 0.7971
# Epoch 14/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.3476 - accuracy: 0.9151 - val_loss: 0.6682 - val_accuracy: 0.8040
# Epoch 15/20
# 51/51 [==============================] - 3s 55ms/step - loss: 0.4080 - accuracy: 0.9081 - val_loss: 0.7558 - val_accuracy: 0.7893
# Epoch 16/20
# 51/51 [==============================] - 3s 54ms/step - loss: 0.3597 - accuracy: 0.9173 - val_loss: 1.0745 - val_accuracy: 0.7145
# Epoch 17/20
# 51/51 [==============================] - 3s 53ms/step - loss: 0.6450 - accuracy: 0.8731 - val_loss: 0.9489 - val_accuracy: 0.7524
# Epoch 18/20
# 51/51 [==============================] - 3s 53ms/step - loss: 0.5772 - accuracy: 0.8778 - val_loss: 1.0383 - val_accuracy: 0.7807
# Epoch 19/20
# 51/51 [==============================] - 3s 53ms/step - loss: 0.3788 - accuracy: 0.9066 - val_loss: 0.7184 - val_accuracy: 0.8255
# Epoch 20/20
# 51/51 [==============================] - 3s 57ms/step - loss: 0.3166 - accuracy: 0.9181 - val_loss: 0.9339 - val_accuracy: 0.7721

# %% [markdown]
# Matrice de confusion data augmentation

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# ...

# Après l'entraînement du modèle
y_pred = model_cnn.predict(data_obs_test_Norm_pad)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(labels_test_onehot, axis=1)

# Calcul de la matrice de confusion
conf_matrix = confusion_matrix(y_true, y_pred_classes)

class_names = np.unique(data_labels)


# Affichage de la matrice de confusion
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Matrice de Confusion')
plt.xlabel('Classe Prédite')
plt.ylabel('Classe Réelle')
plt.show()

# Calcul et affichage de la précision globale
accuracy = accuracy_score(y_true, y_pred_classes)
print(f"Précision globale : {accuracy * 100:.2f}%")
# Out:
# 37/37 [==============================] - 0s 5ms/step
# Précision globale : 81.17%

# %% [markdown]
# Matrice de confusion avec poids attribué aux variables

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# ...

# Après l'entraînement du modèle
y_pred = model_cnn_poids.predict(data_obs_test_Norm_pad)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(labels_test_onehot, axis=1)

# Calcul de la matrice de confusion
conf_matrix = confusion_matrix(y_true, y_pred_classes)

class_names = np.unique(data_labels)


# Affichage de la matrice de confusion
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Matrice de Confusion')
plt.xlabel('Classe Prédite')
plt.ylabel('Classe Réelle')
plt.show()

# Calcul et affichage de la précision globale
accuracy = accuracy_score(y_true, y_pred_classes)
print(f"Précision globale : {accuracy * 100:.2f}%")
# Out:
# 37/37 [==============================] - 0s 5ms/step
# Précision globale : 77.21%

# %% [markdown]
# ## Graphique de comparaison

# %%
# Visualiser l'évolution de la perte et de la précision au fil des époques
import matplotlib.pyplot as plt

plt.subplot(1, 2, 1)
plt.plot(history_rnn_simple.history['val_loss'], label='RNN simple')
plt.plot(history_rnn_data_augment.history['val_loss'], label='RNN avec data augmentée')
plt.plot(history_rnn_poids.history['val_loss'], label='RNN simple avec attribution de poids')
plt.plot(history_rnn_avance.history['val_loss'], label='RNN avancé')
plt.plot(history_lstm.history['val_loss'], label='LSTM')
plt.plot(history_lstm_bidi.history['val_loss'], label='LSTM Bidirectionnal')
plt.plot(history_lstm_avancee.history['val_loss'], label='LSTM avancee')
plt.plot(history_cnn.history['val_loss'], label = 'CNN avec poids')
plt.plot(history_cnn_poids.history['val_loss'], label = 'CNN avec poids')

plt.title('Validation Perte')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_rnn_simple.history['val_accuracy'], label='RNN simple')
plt.plot(history_rnn_data_augment.history['val_accuracy'], label='RNN avec data augmentée')
plt.plot(history_rnn_poids.history['val_accuracy'], label='RNN simple avec attribution de poids')
plt.plot(history_rnn_avance.history['val_accuracy'], label='RNN avancé')
plt.plot(history_lstm.history['val_accuracy'], label='LSTM')
plt.plot(history_lstm_bidi.history['val_accuracy'], label='LSTM Bidirectionnal')
plt.plot(history_lstm_avancee.history['val_accuracy'], label='LSTM avancee')
plt.plot(history_cnn.history['val_accuracy'], label = 'CNN avec poids')
plt.plot(history_cnn_poids.history['val_accuracy'], label = 'CNN avec poids')


plt.title('Validation Accuracy')
plt.legend()

# Ajuster l'espacement entre les sous-graphiques
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# <font color='red'> Pour conclure après avoir essayé différentes transformations de données, les modèles qui semblent les plus précis pour identifier nos données sont :
# *   Le LTSM Bidirectionnal
# *   CNN classique
# Ces modèles paraissent très efficace après une augmentation des données pour avoir des données organisées sans grosses disparités de représentations (au début nous avions seulement 58 sitting sur notre jeu de données de 11000 séries temporelles).
# Nous avons également essayer différentes transformations pour aboutir à de meilleures détections. Dans un premier temps nous avons essayé de travailler sur le processus de normalisation des données (Standardisation vs normalisation vs standardisation percentile (différentes valeurs) vs standardisation Z-score. Nous avons donc après test en validation croisée défini de partit sur un standardisation classique à partir du packages sklearn.
# Par la suite nous avons essayé de transformées nos données pour obte,ir plu d'informations à partir de cela, nous nous sommes intéressés à la vitesse (obtenus à partir de la dérivée de l'accélérations (la problèmatique de la période d'échantillonage c'est posé).
# Nous avons également investigué sur l'utilisation de la variation de position (dérivée secondes de l'accélérations) mais encore la même problématique qui s'est posé.
# Des méthodes de filtrage ont également été testées sans réussite (filtre passe-haut, passe-bas et butterworth). Les résultats n'étaient pas meilleurs.
# Enfin nous avons essayé de travaillé sur le domaine fréquentiel en passant par l'utilisation de la transformée de Fourrier (sans pour autant plus de résultat).
# </font>
